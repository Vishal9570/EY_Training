# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#%matplotlib inline
plt.rcParams['figure.dpi']=110
sns.set_theme(style='whitegrid')
print('libraries loaded')
# Out:
# libraries loaded

# %%
#from google.colab import files
uploaded = files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from google.colab import files
#       2 uploaded = files.upload()
#
# ModuleNotFoundError: No module named 'google'

# %%
df = pd.read_excel('taxis_data.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_excel('taxis_data.xlsx')
#       2 df
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
#     488     raise ValueError(
#     489         "Engine should not be specified when passing "
#     490         "an ExcelFile - ExcelFile already has the engine set"
#     491     )
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\excel\_base.py:1604, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1601         ext = "xls"
#    1603 if ext is None:
# -> 1604     ext = inspect_excel_format(
#    1605         content_or_path=path_or_buffer, storage_options=storage_options
#    1606     )
#    1607     if ext is None:
#    1608         raise ValueError(
#    1609             "Excel file format cannot be determined, you must specify "
#    1610             "an engine manually."
#    1611         )
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\excel\_base.py:1452, in inspect_excel_format(content_or_path, storage_options)
#    1417 def inspect_excel_format(
#    1418     content_or_path: FilePath | ReadBuffer[bytes],
#    1419     storage_options: StorageOptions | None = None,
#    1420 ) -> str | None:
#    1421     """
#    1422     Inspect the path or content of an excel file and get its format.
#    1423
#    (...)   1450         If resulting stream does not have an XLS signature and is not a valid zipfile.
#    1451     """
# -> 1452     with get_handle(
#    1453         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1454     ) as handle:
#    1455         stream = handle.handle
#    1456         stream.seek(0)
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\common.py:939, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#    (...)    935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
# --> 939         handle = open(handle, ioargs.mode)
#     940     handles.append(handle)
#     942 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'taxis_data.xlsx'

# %%
df.shape

# %%
df.head()

# %%
df.tail()

# %%
df.describe()

# %%
df.types

# %%
df.value_counts()

# %%
df.isnull()

# %%
df.isnull().sum()

# %%
print('Shape before cleaning:', df.shape)  #before cleaning

# %%
df.drop(columns=['tip'], inplace=True)  #tip consider as individual

# %%
fare_per_km= df['fare']/df['distance']
fare_per_km

# %%
df.info()

# %%
corr_data = np.corrcoef(df['distance'],df['fare'])
corr_data

# %%
fare_percent = np.percentile(df['fare'],50)
fare_percent

# %%
# Use Pandas groupby with at least 2 different aggregation functions
agg_func = df.groupby('passengers')['fare'].mean()
agg_func

# %%
num_surv= df[df['passengers']==1].groupby('payment')['passengers'].count()
sort_surv= num_surv.sort_values()
sort_surv

# %%
pivot = pd.pivot_table(df,
    values='fare',
    index='payment',
    columns='pickup_zone',
    aggfunc='mean'
)

print(pivot)

# %%
#  summary
total_trips = len(df)
avg_fare = df['fare'].mean()
max_distance = df['distance'].max()
fare_percent = np.percentile(df['fare'], 50)
corr_data = np.corrcoef(df['distance'], df['fare'])[0,1]

print(total_trips)
print(avg_fare)
print(max_distance)
print(fare_percent)
print(corr_data)

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(8,5))

df_100=df.head(100)
sns.scatterplot(data=df_100, x="distance", y="fare")

ax.set_title('Trip Distance vs Fare Amount')

ax.set_xlabel('distance (KM)')

ax.set_ylabel('fare')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 4))
df_100=df.head(100)
# Bar charts look clean and well-spaced when X is a true category with only a few values
sns.barplot(data=df_100, x='payment', y='total')

ax.set_title('Average Total Amount Paid by Payment Type')
ax.set_xlabel('Payment Method')
ax.set_ylabel('Average Total Amount ($)')

plt.tight_layout()
plt.show()

# %%
# Requirement fulfilled: plt.subplots with 2 panels side-by-side
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
df_100=df.head(100)
# Histogram of Distances (Type 3 Chart)
sns.histplot(data=df_100, x='distance', bins=10, color='#2ca02c', kde=True, ax=axes[0])
axes[0].set_title('Distribution of Trip Distances')
axes[0].set_xlabel('Trip Distance (Miles)')
axes[0].set_ylabel('Frequency')

#  Box Plot of Passenger Counts (Type 4 Chart)
sns.boxplot(data=df_100, x='passengers', color='#ff7f0e', ax=axes[1])
axes[1].set_title('Spread of Passenger Counts per Trip')
axes[1].set_xlabel('Number of Passengers')

plt.tight_layout()
plt.show()
